# %%
import pandas as pd
import csv
f = open('Kor_income_training_data.csv', 'r', encoding = 'cp949')
data = csv.reader(f,delimiter = ',')
data = list(data)
f.close()

# %%
new_K = list()
a = 0
for row in data:
    if row[-4] == ' ' and  row[-3] == ' ' and  row[-2] == ' ':
        a += 1
        continue
    new_K.append(row)
print(a)
# Out:
# 1257

# %%
df = pd.DataFrame(new_K)
df.to_csv('KITD_rmv.csv',index = False, header = False)

# %%
new_K = pd.read_csv('KITD_rmv.csv')
new_K
# Out:
#        Unnamed: 0        id  year  wave  region  family_member  gender  \
# 0           77530  68460101  2005     1       3              1       2
# 1           67016  59620101  2018    14       4              3       1
# 2           38931  35960101  2012     8       2              3       1
# 3           72033  63870101  2011     7       4              5       1
# 4           21862  20620101  2017    13       4              2       1
# ...           ...       ...   ...   ...     ...            ...     ...
# 77666       45471  42380101  2007     3       2              4       1
# 77667       27886  26140101  2006     2       2              4       1
# 77668       41941  38910101  2006     2       2              4       1
# 77669       61686  55380101  2018    14       7              1       2
# 77670         759    780101  2007     3       1              3       1
#
#        year_born  education_level  marriage  religion occupation company_size  \
# ...

# %%
f = open('Kor_income_test_data.csv', 'r', encoding = 'cp949')
data = csv.reader(f,delimiter = ',')
data = list(data)
f.close()

# %%
new_K = list()
a = 0
for row in data:
    if row[-4] == ' ' and  row[-3] == ' ' and  row[-2] == ' ':
        a += 1
        continue
    new_K.append(row)
